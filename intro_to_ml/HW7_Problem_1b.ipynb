# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(256 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool1(nn.functional.relu(self.conv1(x)))
        x = self.pool2(nn.functional.relu(self.conv2(x)))
        x = self.pool3(nn.functional.relu(self.conv3(x)))
        x = x.view(-1, 256 * 4 * 4)
        x = nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Set batch size
batch_size = 2048

# Load CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean = [0.5, 0.5, 0.5]
std = [0.5, 0.5, 0.5]
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Initialize the CNN model
model = CNN().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

# Training loop
epochs = 300
init_start_time = time.time()

for epoch in range(epochs):
    start_time = time.time()
    running_loss = 0.0

    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    end_time = time.time()
    training_time = end_time - start_time

    if epoch % 10 == 0:
        print(f'Epoch: {epoch+1}, Loss: {running_loss/len(trainloader)}, Training Time: {training_time:.2f} seconds')

    total_end_time = time.time()
    total_train_time = total_end_time - init_start_time
    print(f'Total Training Time: {total_train_time:.2f} seconds')

    # Validation accuracy
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print(f'Test Accuracy: {100*accuracy:.2f}%')

    model.train()

print(f'Final Test Accuracy: {100*accuracy:.2f}%')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1, Loss: 2.303634719848633, Training Time: 17.66 seconds
# Total Training Time: 17.66 seconds
# Test Accuracy: 9.96%
# Total Training Time: 51.16 seconds
# Test Accuracy: 10.12%
# Total Training Time: 70.05 seconds
# Test Accuracy: 10.46%
# Total Training Time: 88.69 seconds
# Test Accuracy: 10.72%
# Total Training Time: 124.76 seconds
# Test Accuracy: 10.96%
# Total Training Time: 158.30 seconds
# Test Accuracy: 11.28%
# Total Training Time: 193.27 seconds
# Test Accuracy: 11.51%
# Total Training Time: 231.32 seconds
# Test Accuracy: 11.69%
# Total Training Time: 327.84 seconds
# Test Accuracy: 11.73%
# Total Training Time: 458.17 seconds
# Test Accuracy: 11.88%
# Epoch: 11, Loss: 2.301841993331909, Training Time: 23.01 seconds
# Total Training Time: 490.11 seconds
# Test Accuracy: 12.02%
# Total Training Time: 517.09 seconds
# Test Accuracy: 12.16%
# Total Training Time: 541.80 seconds
# Test Accuracy: 12.20%
# Total Training Time: 561.32 seconds
# Test Accuracy: 12.08%
# Total Training Time: 585.41 seconds
# Test Accuracy: 12.05%
# Total Training Time: 603.75 seconds
# Test Accuracy: 11.93%
# Total Training Time: 623.42 seconds
# Test Accuracy: 11.82%
# Total Training Time: 647.42 seconds
# Test Accuracy: 11.81%
# Total Training Time: 667.46 seconds
# Test Accuracy: 11.78%
# Total Training Time: 685.51 seconds
# Test Accuracy: 11.76%
# Epoch: 21, Loss: 2.300101375579834, Training Time: 18.60 seconds
# Total Training Time: 709.71 seconds
# Test Accuracy: 11.75%
# Total Training Time: 730.07 seconds
# Test Accuracy: 11.71%
# Total Training Time: 748.19 seconds
# Test Accuracy: 11.65%
# Total Training Time: 774.17 seconds
# Test Accuracy: 11.74%
# Total Training Time: 792.25 seconds
# Test Accuracy: 11.70%
# Total Training Time: 811.55 seconds
# Test Accuracy: 11.68%
# Total Training Time: 835.79 seconds
# Test Accuracy: 11.59%
# Total Training Time: 854.86 seconds
# Test Accuracy: 11.59%
# Total Training Time: 873.25 seconds
# Test Accuracy: 11.56%
# Total Training Time: 889.28 seconds
# Test Accuracy: 11.58%
# Epoch: 31, Loss: 2.298287858963013, Training Time: 18.51 seconds
# Total Training Time: 913.53 seconds
# Test Accuracy: 11.57%
# Total Training Time: 933.70 seconds
# Test Accuracy: 11.61%
# Total Training Time: 951.82 seconds
# Test Accuracy: 11.65%
# Total Training Time: 976.60 seconds
# Test Accuracy: 11.68%
# Total Training Time: 995.31 seconds
# Test Accuracy: 11.66%
# Total Training Time: 1014.90 seconds
# Test Accuracy: 11.69%
# Total Training Time: 1039.19 seconds
# Test Accuracy: 11.71%
# Total Training Time: 1057.85 seconds
# Test Accuracy: 11.60%
# Total Training Time: 1076.03 seconds
# Test Accuracy: 11.64%
# Total Training Time: 1100.28 seconds
# Test Accuracy: 11.67%
# Epoch: 41, Loss: 2.2965038299560545, Training Time: 14.71 seconds
# Total Training Time: 1120.54 seconds
# Test Accuracy: 11.71%
# Total Training Time: 1138.42 seconds
# Test Accuracy: 11.78%
# Total Training Time: 1161.95 seconds
# Test Accuracy: 11.84%
# Total Training Time: 1180.29 seconds
# Test Accuracy: 11.90%
# Total Training Time: 1199.49 seconds
# Test Accuracy: 11.89%
# Total Training Time: 1224.93 seconds
# Test Accuracy: 11.88%
# Total Training Time: 1243.79 seconds
# Test Accuracy: 11.92%
# Total Training Time: 1264.60 seconds
# Test Accuracy: 11.98%
# Total Training Time: 1288.71 seconds
# Test Accuracy: 12.10%
# Total Training Time: 1307.72 seconds
# Test Accuracy: 12.12%
# Epoch: 51, Loss: 2.2946370124816893, Training Time: 13.03 seconds
# Total Training Time: 1326.43 seconds
# Test Accuracy: 12.13%
# Total Training Time: 1350.48 seconds
# Test Accuracy: 12.23%
# Total Training Time: 1370.71 seconds
# Test Accuracy: 12.28%
# Total Training Time: 1390.56 seconds
# Test Accuracy: 12.31%
# Total Training Time: 1414.59 seconds
# Test Accuracy: 12.37%
# Total Training Time: 1432.74 seconds
# Test Accuracy: 12.38%
# Total Training Time: 1450.90 seconds
# Test Accuracy: 12.39%
# Total Training Time: 1475.24 seconds
# Test Accuracy: 12.41%
# Total Training Time: 1495.32 seconds
# Test Accuracy: 12.44%
# Total Training Time: 1513.33 seconds
# Test Accuracy: 12.43%
# Epoch: 61, Loss: 2.292512922286987, Training Time: 18.33 seconds
# Total Training Time: 1537.24 seconds
# Test Accuracy: 12.42%
# Total Training Time: 1555.47 seconds
# Test Accuracy: 12.43%
# Total Training Time: 1576.04 seconds
# Test Accuracy: 12.43%
# Total Training Time: 1599.33 seconds
# Test Accuracy: 12.51%
# Total Training Time: 1618.03 seconds
# Test Accuracy: 12.50%
# Total Training Time: 1637.69 seconds
# Test Accuracy: 12.49%
# Total Training Time: 1662.42 seconds
# Test Accuracy: 12.54%
# Total Training Time: 1681.04 seconds
# Test Accuracy: 12.57%
# Total Training Time: 1699.89 seconds
# Test Accuracy: 12.57%
# Total Training Time: 1724.05 seconds
# Test Accuracy: 12.56%
# Epoch: 71, Loss: 2.2902555084228515, Training Time: 14.77 seconds
# Total Training Time: 1744.58 seconds
# Test Accuracy: 12.55%
# Total Training Time: 1764.08 seconds
# Test Accuracy: 12.49%
# Total Training Time: 1788.35 seconds
# Test Accuracy: 12.54%
# Total Training Time: 1806.71 seconds
# Test Accuracy: 12.57%
# Total Training Time: 1825.87 seconds
# Test Accuracy: 12.60%
# Total Training Time: 1849.73 seconds
# Test Accuracy: 12.60%
# Total Training Time: 1868.14 seconds
# Test Accuracy: 12.63%
# Total Training Time: 1887.47 seconds
# Test Accuracy: 12.67%
# Total Training Time: 1911.57 seconds
# Test Accuracy: 12.72%
# Total Training Time: 1930.13 seconds
# Test Accuracy: 12.73%
# Epoch: 81, Loss: 2.287661600112915, Training Time: 12.51 seconds
# Total Training Time: 1949.69 seconds
# Test Accuracy: 12.72%
# Total Training Time: 1974.89 seconds
# Test Accuracy: 12.79%
# Total Training Time: 1993.53 seconds
# Test Accuracy: 12.84%
# Total Training Time: 2011.74 seconds
# Test Accuracy: 12.84%
# Total Training Time: 2036.57 seconds
# Test Accuracy: 12.83%
# Total Training Time: 2055.19 seconds
# Test Accuracy: 12.89%
# Total Training Time: 2075.15 seconds
# Test Accuracy: 12.90%
# Total Training Time: 2099.80 seconds
# Test Accuracy: 12.96%
# Total Training Time: 2118.72 seconds
# Test Accuracy: 12.99%
# Total Training Time: 2136.74 seconds
# Test Accuracy: 13.00%
# Epoch: 91, Loss: 2.2846104431152345, Training Time: 18.71 seconds
# Total Training Time: 2161.37 seconds
# Test Accuracy: 12.98%
# Total Training Time: 2180.07 seconds
# Test Accuracy: 12.97%
# Total Training Time: 2198.22 seconds
# Test Accuracy: 12.98%
# Total Training Time: 2222.67 seconds
# Test Accuracy: 13.04%
# Total Training Time: 2241.07 seconds
# Test Accuracy: 13.08%
# Total Training Time: 2260.87 seconds
# Test Accuracy: 13.09%
# Total Training Time: 2285.10 seconds
# Test Accuracy: 13.09%
# Total Training Time: 2303.45 seconds
# Test Accuracy: 13.07%
# Total Training Time: 2321.72 seconds
# Test Accuracy: 13.12%
# Total Training Time: 2345.96 seconds
# Test Accuracy: 13.19%
# Epoch: 101, Loss: 2.281131610870361, Training Time: 12.87 seconds
# Total Training Time: 2364.57 seconds
# Test Accuracy: 13.26%
# Total Training Time: 2382.93 seconds
# Test Accuracy: 13.30%
# Total Training Time: 2400.86 seconds
# Test Accuracy: 13.39%
# Total Training Time: 2425.02 seconds
# Test Accuracy: 13.53%
# Total Training Time: 2443.45 seconds
# Test Accuracy: 13.65%
# Total Training Time: 2461.91 seconds
# Test Accuracy: 13.73%
# Total Training Time: 2487.46 seconds
# Test Accuracy: 13.81%
# Total Training Time: 2506.02 seconds
# Test Accuracy: 13.93%
# Total Training Time: 2526.61 seconds
# Test Accuracy: 14.03%
# Total Training Time: 2567.35 seconds
# Test Accuracy: 14.14%
# Epoch: 111, Loss: 2.2768209552764893, Training Time: 48.88 seconds
# Total Training Time: 2622.32 seconds
# Test Accuracy: 14.19%
# Total Training Time: 2670.93 seconds
# Test Accuracy: 14.43%
# Total Training Time: 2715.50 seconds
# Test Accuracy: 14.67%
# Total Training Time: 2758.16 seconds
# Test Accuracy: 14.82%
# Total Training Time: 2795.64 seconds
# Test Accuracy: 14.95%
# Total Training Time: 2829.23 seconds
# Test Accuracy: 15.07%
# Total Training Time: 2863.77 seconds
# Test Accuracy: 15.20%
# Total Training Time: 2910.40 seconds
# Test Accuracy: 15.37%
# Total Training Time: 3202.13 seconds
# Test Accuracy: 15.57%
# Total Training Time: 3244.40 seconds
# Test Accuracy: 15.71%
# Epoch: 121, Loss: 2.2715829277038573, Training Time: 29.01 seconds
# Total Training Time: 3280.34 seconds
# Test Accuracy: 15.88%
# Total Training Time: 3316.34 seconds
# Test Accuracy: 15.99%
# Total Training Time: 3351.32 seconds
# Test Accuracy: 16.10%
# Total Training Time: 3385.43 seconds
# Test Accuracy: 16.33%
# Total Training Time: 3419.22 seconds
# Test Accuracy: 16.51%
# Total Training Time: 3453.51 seconds
# Test Accuracy: 16.67%
# Total Training Time: 3486.31 seconds
# Test Accuracy: 16.77%
# Total Training Time: 3518.76 seconds
# Test Accuracy: 16.95%
# Total Training Time: 3552.06 seconds
# Test Accuracy: 17.22%
# Total Training Time: 3586.13 seconds
# Test Accuracy: 17.39%
# Epoch: 131, Loss: 2.2649092960357664, Training Time: 28.29 seconds
# Total Training Time: 3620.22 seconds
# Test Accuracy: 17.47%
# Total Training Time: 3652.83 seconds
# Test Accuracy: 17.73%
# Total Training Time: 3685.64 seconds
# Test Accuracy: 17.94%
# Total Training Time: 3719.52 seconds
# Test Accuracy: 18.15%
# Total Training Time: 3753.69 seconds
# Test Accuracy: 18.36%
# Total Training Time: 3789.78 seconds
# Test Accuracy: 18.63%
# Total Training Time: 3826.10 seconds
# Test Accuracy: 18.87%
# Total Training Time: 3872.03 seconds
# Test Accuracy: 19.02%
# Total Training Time: 3909.71 seconds
# Test Accuracy: 19.22%
# Total Training Time: 3941.92 seconds
# Test Accuracy: 19.48%
# Epoch: 141, Loss: 2.256548900604248, Training Time: 24.44 seconds
# Total Training Time: 3971.91 seconds
# Test Accuracy: 19.66%
# Total Training Time: 4001.74 seconds
# Test Accuracy: 19.82%
# Total Training Time: 4052.70 seconds
# Test Accuracy: 20.01%
# Total Training Time: 4087.57 seconds
# Test Accuracy: 20.18%
# Total Training Time: 4119.86 seconds
# Test Accuracy: 20.35%
# Total Training Time: 4157.38 seconds
# Test Accuracy: 20.53%
# Total Training Time: 4191.56 seconds
# Test Accuracy: 20.72%
# Total Training Time: 4226.67 seconds
# Test Accuracy: 20.91%
# Total Training Time: 4256.98 seconds
# Test Accuracy: 21.11%
# Total Training Time: 4291.78 seconds
# Test Accuracy: 21.33%
# Epoch: 151, Loss: 2.2461874866485596, Training Time: 28.26 seconds
# Total Training Time: 4325.63 seconds
# Test Accuracy: 21.61%
# Total Training Time: 4367.69 seconds
# Test Accuracy: 21.80%
# Total Training Time: 4382.32 seconds
# Test Accuracy: 22.16%
# Total Training Time: 4397.24 seconds
# Test Accuracy: 22.41%
# Total Training Time: 4411.67 seconds
# Test Accuracy: 22.54%
# Total Training Time: 4426.31 seconds
# Test Accuracy: 22.69%
# Total Training Time: 4440.87 seconds
# Test Accuracy: 22.85%
# Total Training Time: 4455.33 seconds
# Test Accuracy: 22.90%
# Total Training Time: 4469.87 seconds
# Test Accuracy: 22.90%
# Total Training Time: 4485.53 seconds
# Test Accuracy: 23.05%
# Epoch: 161, Loss: 2.232694664001465, Training Time: 9.68 seconds
# Total Training Time: 4500.30 seconds
# Test Accuracy: 23.13%
# Total Training Time: 4515.16 seconds
# Test Accuracy: 23.20%
# Total Training Time: 4530.02 seconds
# Test Accuracy: 23.34%
# Total Training Time: 4544.89 seconds
# Test Accuracy: 23.48%
# Total Training Time: 4560.37 seconds
# Test Accuracy: 23.58%
# Total Training Time: 4575.91 seconds
# Test Accuracy: 23.66%
# Total Training Time: 4590.70 seconds
# Test Accuracy: 23.82%
# Total Training Time: 4606.12 seconds
# Test Accuracy: 23.96%
# Total Training Time: 4621.69 seconds
# Test Accuracy: 23.98%
# Total Training Time: 4636.34 seconds
# Test Accuracy: 24.13%
# Epoch: 171, Loss: 2.2159172821044923, Training Time: 9.47 seconds
# Total Training Time: 4650.77 seconds
# Test Accuracy: 24.26%
# Total Training Time: 4665.21 seconds
# Test Accuracy: 24.34%
# Total Training Time: 4679.78 seconds
# Test Accuracy: 24.45%
# Total Training Time: 4694.33 seconds
# Test Accuracy: 24.56%
# Total Training Time: 4708.80 seconds
# Test Accuracy: 24.59%
# Total Training Time: 4723.32 seconds
# Test Accuracy: 24.70%
# Total Training Time: 4738.34 seconds
# Test Accuracy: 24.74%
# Total Training Time: 4752.76 seconds
# Test Accuracy: 24.71%
# Total Training Time: 4767.31 seconds
# Test Accuracy: 24.86%
# Total Training Time: 4781.79 seconds
# Test Accuracy: 24.96%
# Epoch: 181, Loss: 2.195531644821167, Training Time: 9.54 seconds
# Total Training Time: 4796.32 seconds
# Test Accuracy: 25.06%
# Total Training Time: 4810.86 seconds
# Test Accuracy: 25.13%
# Total Training Time: 4825.23 seconds
# Test Accuracy: 25.21%
# Total Training Time: 4839.71 seconds
# Test Accuracy: 25.27%
# Total Training Time: 4854.24 seconds
# Test Accuracy: 25.47%
# Total Training Time: 4868.79 seconds
# Test Accuracy: 25.58%
# Total Training Time: 4883.35 seconds
# Test Accuracy: 25.71%
# Total Training Time: 4898.12 seconds
# Test Accuracy: 25.65%
# Total Training Time: 4912.79 seconds
# Test Accuracy: 25.67%
# Total Training Time: 4927.40 seconds
# Test Accuracy: 25.68%
# Epoch: 191, Loss: 2.171501407623291, Training Time: 9.48 seconds
# Total Training Time: 4941.85 seconds
# Test Accuracy: 25.79%
# Total Training Time: 4956.32 seconds
# Test Accuracy: 25.85%
# Total Training Time: 4970.86 seconds
# Test Accuracy: 25.92%
# Total Training Time: 4985.35 seconds
# Test Accuracy: 26.01%
# Total Training Time: 4999.83 seconds
# Test Accuracy: 26.06%
# Total Training Time: 5014.34 seconds
# Test Accuracy: 26.06%
# Total Training Time: 5028.88 seconds
# Test Accuracy: 26.15%
# Total Training Time: 5043.52 seconds
# Test Accuracy: 26.17%
# Total Training Time: 5058.09 seconds
# Test Accuracy: 26.13%
# Total Training Time: 5072.67 seconds
# Test Accuracy: 26.17%
# Epoch: 201, Loss: 2.145706977844238, Training Time: 9.49 seconds
# Total Training Time: 5087.16 seconds
# Test Accuracy: 26.18%
# Total Training Time: 5101.73 seconds
# Test Accuracy: 26.24%
# Total Training Time: 5116.25 seconds
# Test Accuracy: 26.31%
# Total Training Time: 5130.74 seconds
# Test Accuracy: 26.38%
# Total Training Time: 5145.34 seconds
# Test Accuracy: 26.42%
# Total Training Time: 5159.91 seconds
# Test Accuracy: 26.47%
# Total Training Time: 5174.45 seconds
# Test Accuracy: 26.49%
# Total Training Time: 5189.02 seconds
# Test Accuracy: 26.52%
# Total Training Time: 5203.63 seconds
# Test Accuracy: 26.58%
# Total Training Time: 5218.21 seconds
# Test Accuracy: 26.61%
# Epoch: 211, Loss: 2.1202055740356447, Training Time: 9.62 seconds
# Total Training Time: 5232.80 seconds
# Test Accuracy: 26.64%
# Total Training Time: 5247.42 seconds
# Test Accuracy: 26.60%
# Total Training Time: 5261.90 seconds
# Test Accuracy: 26.69%
# Total Training Time: 5276.48 seconds
# Test Accuracy: 26.73%
# Total Training Time: 5291.18 seconds
# Test Accuracy: 26.79%
# Total Training Time: 5305.78 seconds
# Test Accuracy: 26.81%
# Total Training Time: 5320.24 seconds
# Test Accuracy: 26.88%
# Total Training Time: 5334.78 seconds
# Test Accuracy: 26.94%
# Total Training Time: 5349.39 seconds
# Test Accuracy: 26.94%
# Total Training Time: 5364.03 seconds
# Test Accuracy: 26.92%
# Epoch: 221, Loss: 2.0953745651245117, Training Time: 9.53 seconds
# Total Training Time: 5378.55 seconds
# Test Accuracy: 26.94%
# Total Training Time: 5393.07 seconds
# Test Accuracy: 27.02%
# Total Training Time: 5407.68 seconds
# Test Accuracy: 27.09%
# Total Training Time: 5422.32 seconds
# Test Accuracy: 27.18%
# Total Training Time: 5436.84 seconds
# Test Accuracy: 27.25%
# Total Training Time: 5451.34 seconds
# Test Accuracy: 27.28%
# Total Training Time: 5465.78 seconds
# Test Accuracy: 27.35%
# Total Training Time: 5480.36 seconds
# Test Accuracy: 27.40%
# Total Training Time: 5494.91 seconds
# Test Accuracy: 27.44%
# Total Training Time: 5509.41 seconds
# Test Accuracy: 27.49%
# Epoch: 231, Loss: 2.072857313156128, Training Time: 9.51 seconds
# Total Training Time: 5523.93 seconds
# Test Accuracy: 27.55%
# Total Training Time: 5538.37 seconds
# Test Accuracy: 27.60%
# Total Training Time: 5552.81 seconds
# Test Accuracy: 27.64%
# Total Training Time: 5567.31 seconds
# Test Accuracy: 27.61%
# Total Training Time: 5581.81 seconds
# Test Accuracy: 27.65%
# Total Training Time: 5596.36 seconds
# Test Accuracy: 27.68%
# Total Training Time: 5610.85 seconds
# Test Accuracy: 27.77%
# Total Training Time: 5625.27 seconds
# Test Accuracy: 27.76%
# Total Training Time: 5639.83 seconds
# Test Accuracy: 27.79%
# Total Training Time: 5654.40 seconds
# Test Accuracy: 27.82%
# Epoch: 241, Loss: 2.0509982204437254, Training Time: 9.59 seconds
# Total Training Time: 5669.00 seconds
# Test Accuracy: 27.85%
# Total Training Time: 5683.44 seconds
# Test Accuracy: 27.86%
# Total Training Time: 5697.90 seconds
# Test Accuracy: 27.91%
# Total Training Time: 5712.42 seconds
# Test Accuracy: 28.02%
# Total Training Time: 5726.95 seconds
# Test Accuracy: 28.10%
# Total Training Time: 5741.46 seconds
# Test Accuracy: 28.20%
# Total Training Time: 5755.97 seconds
# Test Accuracy: 28.27%
# Total Training Time: 5770.51 seconds
# Test Accuracy: 28.36%
# Total Training Time: 5785.08 seconds
# Test Accuracy: 28.41%
# Total Training Time: 5799.57 seconds
# Test Accuracy: 28.43%
# Epoch: 251, Loss: 2.029834756851196, Training Time: 9.73 seconds
# Total Training Time: 5814.40 seconds
# Test Accuracy: 28.49%
# Total Training Time: 5828.98 seconds
# Test Accuracy: 28.62%
# Total Training Time: 5843.48 seconds
# Test Accuracy: 28.68%
# Total Training Time: 5858.08 seconds
# Test Accuracy: 28.74%
# Total Training Time: 5872.55 seconds
# Test Accuracy: 28.84%
# Total Training Time: 5887.08 seconds
# Test Accuracy: 28.88%
# Total Training Time: 5901.57 seconds
# Test Accuracy: 28.98%
# Total Training Time: 5916.15 seconds
# Test Accuracy: 29.09%
# Total Training Time: 5930.62 seconds
# Test Accuracy: 29.09%
# Total Training Time: 5945.13 seconds
# Test Accuracy: 29.18%
# Epoch: 261, Loss: 2.0095267581939695, Training Time: 9.53 seconds
# Total Training Time: 5959.66 seconds
# Test Accuracy: 29.23%
# Total Training Time: 5974.21 seconds
# Test Accuracy: 29.29%
# Total Training Time: 5988.79 seconds
# Test Accuracy: 29.32%
# Total Training Time: 6003.22 seconds
# Test Accuracy: 29.49%
# Total Training Time: 6017.77 seconds
# Test Accuracy: 29.46%
# Total Training Time: 6032.29 seconds
# Test Accuracy: 29.55%
# Total Training Time: 6046.76 seconds
# Test Accuracy: 29.59%
# Total Training Time: 6061.33 seconds
# Test Accuracy: 29.66%
# Total Training Time: 6075.77 seconds
# Test Accuracy: 29.74%
# Total Training Time: 6090.20 seconds
# Test Accuracy: 29.80%
# Epoch: 271, Loss: 1.9900619792938232, Training Time: 9.53 seconds
# Total Training Time: 6104.75 seconds
# Test Accuracy: 29.84%
# Total Training Time: 6119.27 seconds
# Test Accuracy: 29.88%
# Total Training Time: 6133.78 seconds
# Test Accuracy: 29.91%
# Total Training Time: 6148.31 seconds
# Test Accuracy: 29.94%
# Total Training Time: 6162.79 seconds
# Test Accuracy: 30.01%
# Total Training Time: 6177.32 seconds
# Test Accuracy: 30.09%
# Total Training Time: 6191.84 seconds
# Test Accuracy: 30.18%
# Total Training Time: 6206.50 seconds
# Test Accuracy: 30.26%
# Total Training Time: 6220.94 seconds
# Test Accuracy: 30.28%
# Total Training Time: 6235.41 seconds
# Test Accuracy: 30.43%
# Epoch: 281, Loss: 1.970542402267456, Training Time: 9.43 seconds
# Total Training Time: 6249.79 seconds
# Test Accuracy: 30.46%
# Total Training Time: 6264.22 seconds
# Test Accuracy: 30.47%
# Total Training Time: 6278.67 seconds
# Test Accuracy: 30.59%
# Total Training Time: 6293.10 seconds
# Test Accuracy: 30.63%
# Total Training Time: 6307.58 seconds
# Test Accuracy: 30.69%
# Total Training Time: 6322.04 seconds
# Test Accuracy: 30.71%
# Total Training Time: 6336.54 seconds
# Test Accuracy: 30.72%
# Total Training Time: 6351.09 seconds
# Test Accuracy: 30.74%
# Total Training Time: 6365.65 seconds
# Test Accuracy: 30.75%
# Total Training Time: 6380.11 seconds
# Test Accuracy: 30.77%
# Epoch: 291, Loss: 1.9534668111801148, Training Time: 9.50 seconds
# Total Training Time: 6394.52 seconds
# Test Accuracy: 30.83%
# Total Training Time: 6408.97 seconds
# Test Accuracy: 30.81%
# Total Training Time: 6423.45 seconds
# Test Accuracy: 30.93%
# Total Training Time: 6437.90 seconds
# Test Accuracy: 30.98%
# Total Training Time: 6452.41 seconds
# Test Accuracy: 31.06%
# Total Training Time: 6466.90 seconds
# Test Accuracy: 31.08%
# Total Training Time: 6481.40 seconds
# Test Accuracy: 31.18%
# Total Training Time: 6495.93 seconds
# Test Accuracy: 31.18%
# Total Training Time: 6510.43 seconds
# Test Accuracy: 31.25%
# Total Training Time: 6524.92 seconds
# Test Accuracy: 31.28%
# Final Test Accuracy: 31.28%

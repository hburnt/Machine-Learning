# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool1(nn.functional.relu(self.conv1(x)))
        x = self.pool2(nn.functional.relu(self.conv2(x)))
        x = x.view(-1, 128 * 8 * 8)
        x = nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Set batch size
batch_size = 2048

# Load CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean = [0.5, 0.5, 0.5]
std = [0.5, 0.5, 0.5]
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Initialize the CNN model
model = CNN().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

# Training loop
epochs = 300
init_start_time = time.time()

for epoch in range(epochs):
    start_time = time.time()
    running_loss = 0.0

    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    end_time = time.time()
    training_time = end_time - start_time

    if epoch % 10 == 0:
        print(f'Epoch: {epoch+1}, Loss: {running_loss/len(trainloader)}, Training Time: {training_time:.2f} seconds')

    total_end_time = time.time()
    total_train_time = total_end_time - init_start_time
    print(f'Total Training Time: {total_train_time:.2f} seconds')

    # Validation accuracy
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print(f'Test Accuracy: {100*accuracy:.2f}%')

    model.train()

print(f'Final Test Accuracy: {100*accuracy:.2f}%')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1, Loss: 2.302675313949585, Training Time: 9.96 seconds
# Total Training Time: 9.96 seconds
# Test Accuracy: 12.67%
# Total Training Time: 24.05 seconds
# Test Accuracy: 12.90%
# Total Training Time: 37.99 seconds
# Test Accuracy: 12.95%
# Total Training Time: 52.05 seconds
# Test Accuracy: 12.83%
# Total Training Time: 65.99 seconds
# Test Accuracy: 12.78%
# Total Training Time: 79.90 seconds
# Test Accuracy: 12.73%
# Total Training Time: 93.87 seconds
# Test Accuracy: 12.77%
# Total Training Time: 107.98 seconds
# Test Accuracy: 12.81%
# Total Training Time: 121.92 seconds
# Test Accuracy: 12.93%
# Total Training Time: 135.86 seconds
# Test Accuracy: 13.15%
# Epoch: 11, Loss: 2.2906062698364256, Training Time: 9.10 seconds
# Total Training Time: 149.85 seconds
# Test Accuracy: 13.43%
# Total Training Time: 163.80 seconds
# Test Accuracy: 13.72%
# Total Training Time: 177.79 seconds
# Test Accuracy: 14.06%
# Total Training Time: 191.87 seconds
# Test Accuracy: 14.38%
# Total Training Time: 205.93 seconds
# Test Accuracy: 14.90%
# Total Training Time: 219.99 seconds
# Test Accuracy: 15.35%
# Total Training Time: 234.02 seconds
# Test Accuracy: 15.81%
# Total Training Time: 247.97 seconds
# Test Accuracy: 16.46%
# Total Training Time: 261.92 seconds
# Test Accuracy: 16.93%
# Total Training Time: 276.07 seconds
# Test Accuracy: 17.32%
# Epoch: 21, Loss: 2.2781567478179934, Training Time: 9.11 seconds
# Total Training Time: 290.09 seconds
# Test Accuracy: 17.64%
# Total Training Time: 304.00 seconds
# Test Accuracy: 18.08%
# Total Training Time: 318.04 seconds
# Test Accuracy: 18.49%
# Total Training Time: 332.01 seconds
# Test Accuracy: 18.97%
# Total Training Time: 345.92 seconds
# Test Accuracy: 19.18%
# Total Training Time: 359.86 seconds
# Test Accuracy: 19.61%
# Total Training Time: 373.72 seconds
# Test Accuracy: 19.91%
# Total Training Time: 387.71 seconds
# Test Accuracy: 20.20%
# Total Training Time: 401.64 seconds
# Test Accuracy: 20.51%
# Total Training Time: 415.57 seconds
# Test Accuracy: 20.83%
# Epoch: 31, Loss: 2.2631103515625, Training Time: 9.09 seconds
# Total Training Time: 429.53 seconds
# Test Accuracy: 21.01%
# Total Training Time: 443.56 seconds
# Test Accuracy: 21.44%
# Total Training Time: 457.69 seconds
# Test Accuracy: 21.69%
# Total Training Time: 471.59 seconds
# Test Accuracy: 22.07%
# Total Training Time: 485.56 seconds
# Test Accuracy: 22.31%
# Total Training Time: 499.53 seconds
# Test Accuracy: 22.57%
# Total Training Time: 513.55 seconds
# Test Accuracy: 22.80%
# Total Training Time: 527.46 seconds
# Test Accuracy: 23.05%
# Total Training Time: 541.47 seconds
# Test Accuracy: 23.24%
# Total Training Time: 555.37 seconds
# Test Accuracy: 23.46%
# Epoch: 41, Loss: 2.243810091018677, Training Time: 9.02 seconds
# Total Training Time: 569.24 seconds
# Test Accuracy: 23.64%
# Total Training Time: 583.38 seconds
# Test Accuracy: 23.81%
# Total Training Time: 597.47 seconds
# Test Accuracy: 24.06%
# Total Training Time: 611.47 seconds
# Test Accuracy: 24.15%
# Total Training Time: 625.41 seconds
# Test Accuracy: 24.32%
# Total Training Time: 639.42 seconds
# Test Accuracy: 24.50%
# Total Training Time: 653.92 seconds
# Test Accuracy: 24.58%
# Total Training Time: 667.88 seconds
# Test Accuracy: 24.69%
# Total Training Time: 681.94 seconds
# Test Accuracy: 24.90%
# Total Training Time: 695.99 seconds
# Test Accuracy: 25.01%
# Epoch: 51, Loss: 2.2197372245788576, Training Time: 9.06 seconds
# Total Training Time: 709.93 seconds
# Test Accuracy: 25.17%
# Total Training Time: 723.92 seconds
# Test Accuracy: 25.33%
# Total Training Time: 737.97 seconds
# Test Accuracy: 25.32%
# Total Training Time: 751.99 seconds
# Test Accuracy: 25.26%
# Total Training Time: 766.00 seconds
# Test Accuracy: 25.41%
# Total Training Time: 780.04 seconds
# Test Accuracy: 25.48%
# Total Training Time: 793.99 seconds
# Test Accuracy: 25.54%
# Total Training Time: 808.15 seconds
# Test Accuracy: 25.56%
# Total Training Time: 822.18 seconds
# Test Accuracy: 25.73%
# Total Training Time: 836.37 seconds
# Test Accuracy: 25.87%
# Epoch: 61, Loss: 2.1912405014038088, Training Time: 9.18 seconds
# Total Training Time: 850.55 seconds
# Test Accuracy: 25.96%
# Total Training Time: 864.73 seconds
# Test Accuracy: 25.98%
# Total Training Time: 878.70 seconds
# Test Accuracy: 26.04%
# Total Training Time: 892.72 seconds
# Test Accuracy: 26.15%
# Total Training Time: 906.75 seconds
# Test Accuracy: 26.22%
# Total Training Time: 920.80 seconds
# Test Accuracy: 26.25%
# Total Training Time: 934.86 seconds
# Test Accuracy: 26.34%
# Total Training Time: 948.92 seconds
# Test Accuracy: 26.34%
# Total Training Time: 962.90 seconds
# Test Accuracy: 26.43%
# Total Training Time: 976.87 seconds
# Test Accuracy: 26.46%
# Epoch: 71, Loss: 2.159667663574219, Training Time: 9.28 seconds
# Total Training Time: 991.07 seconds
# Test Accuracy: 26.55%
# Total Training Time: 1005.32 seconds
# Test Accuracy: 26.58%
# Total Training Time: 1019.35 seconds
# Test Accuracy: 26.62%
# Total Training Time: 1033.56 seconds
# Test Accuracy: 26.69%
# Total Training Time: 1047.67 seconds
# Test Accuracy: 26.69%
# Total Training Time: 1061.70 seconds
# Test Accuracy: 26.76%
# Total Training Time: 1075.81 seconds
# Test Accuracy: 26.82%
# Total Training Time: 1089.78 seconds
# Test Accuracy: 26.90%
# Total Training Time: 1103.76 seconds
# Test Accuracy: 26.94%
# Total Training Time: 1117.91 seconds
# Test Accuracy: 27.03%
# Epoch: 81, Loss: 2.127965393066406, Training Time: 9.20 seconds
# Total Training Time: 1132.07 seconds
# Test Accuracy: 27.10%
# Total Training Time: 1146.22 seconds
# Test Accuracy: 27.14%
# Total Training Time: 1160.39 seconds
# Test Accuracy: 27.21%
# Total Training Time: 1174.79 seconds
# Test Accuracy: 27.22%
# Total Training Time: 1194.73 seconds
# Test Accuracy: 27.33%
# Total Training Time: 1224.00 seconds
# Test Accuracy: 27.26%
# Total Training Time: 1240.42 seconds
# Test Accuracy: 27.20%
# Total Training Time: 1256.98 seconds
# Test Accuracy: 27.29%
# Total Training Time: 1273.06 seconds
# Test Accuracy: 27.35%
# Total Training Time: 1288.44 seconds
# Test Accuracy: 27.37%
# Epoch: 91, Loss: 2.0981622695922852, Training Time: 10.08 seconds
# Total Training Time: 1303.86 seconds
# Test Accuracy: 27.47%
# Total Training Time: 1318.81 seconds
# Test Accuracy: 27.45%
# Total Training Time: 1334.13 seconds
# Test Accuracy: 27.54%
# Total Training Time: 1348.66 seconds
# Test Accuracy: 27.51%
# Total Training Time: 1364.63 seconds
# Test Accuracy: 27.57%
# Total Training Time: 1379.84 seconds
# Test Accuracy: 27.62%
# Total Training Time: 1395.68 seconds
# Test Accuracy: 27.61%
# Total Training Time: 1411.40 seconds
# Test Accuracy: 27.69%
# Total Training Time: 1426.34 seconds
# Test Accuracy: 27.78%
# Total Training Time: 1444.42 seconds
# Test Accuracy: 27.83%
# Epoch: 101, Loss: 2.07116512298584, Training Time: 34.86 seconds
# Total Training Time: 1492.02 seconds
# Test Accuracy: 27.89%
# Total Training Time: 1531.84 seconds
# Test Accuracy: 27.89%
# Total Training Time: 1582.24 seconds
# Test Accuracy: 28.03%
# Total Training Time: 1628.39 seconds
# Test Accuracy: 28.07%
# Total Training Time: 1645.45 seconds
# Test Accuracy: 28.12%
# Total Training Time: 1662.58 seconds
# Test Accuracy: 28.17%
# Total Training Time: 1680.60 seconds
# Test Accuracy: 28.15%
# Total Training Time: 1698.75 seconds
# Test Accuracy: 28.13%
# Total Training Time: 1715.38 seconds
# Test Accuracy: 28.22%
# Total Training Time: 1731.22 seconds
# Test Accuracy: 28.33%
# Epoch: 111, Loss: 2.0471086883544922, Training Time: 9.40 seconds
# Total Training Time: 1745.86 seconds
# Test Accuracy: 28.36%
# Total Training Time: 1762.21 seconds
# Test Accuracy: 28.38%
# Total Training Time: 1777.16 seconds
# Test Accuracy: 28.50%
# Total Training Time: 1792.93 seconds
# Test Accuracy: 28.59%
# Total Training Time: 1807.79 seconds
# Test Accuracy: 28.60%
# Total Training Time: 1824.44 seconds
# Test Accuracy: 28.74%
# Total Training Time: 1838.95 seconds
# Test Accuracy: 28.82%
# Total Training Time: 1854.55 seconds
# Test Accuracy: 28.90%
# Total Training Time: 1869.98 seconds
# Test Accuracy: 28.97%
# Total Training Time: 1886.63 seconds
# Test Accuracy: 29.08%
# Epoch: 121, Loss: 2.024435896873474, Training Time: 9.53 seconds
# Total Training Time: 1901.21 seconds
# Test Accuracy: 29.09%
# Total Training Time: 1916.86 seconds
# Test Accuracy: 29.13%
# Total Training Time: 1932.60 seconds
# Test Accuracy: 29.16%
# Total Training Time: 1951.05 seconds
# Test Accuracy: 29.23%
# Total Training Time: 1965.47 seconds
# Test Accuracy: 29.24%
# Total Training Time: 1981.01 seconds
# Test Accuracy: 29.32%
# Total Training Time: 1996.00 seconds
# Test Accuracy: 29.42%
# Total Training Time: 2012.41 seconds
# Test Accuracy: 29.54%
# Total Training Time: 2027.48 seconds
# Test Accuracy: 29.61%
# Total Training Time: 2043.58 seconds
# Test Accuracy: 29.69%
# Epoch: 131, Loss: 2.0025879764556884, Training Time: 11.00 seconds
# Total Training Time: 2059.68 seconds
# Test Accuracy: 29.72%
# Total Training Time: 2074.23 seconds
# Test Accuracy: 29.83%
# Total Training Time: 2090.66 seconds
# Test Accuracy: 29.91%
# Total Training Time: 2106.29 seconds
# Test Accuracy: 29.98%
# Total Training Time: 2121.90 seconds
# Test Accuracy: 30.09%
# Total Training Time: 2136.56 seconds
# Test Accuracy: 30.10%
# Total Training Time: 2153.28 seconds
# Test Accuracy: 30.19%
# Total Training Time: 2168.06 seconds
# Test Accuracy: 30.25%
# Total Training Time: 2184.37 seconds
# Test Accuracy: 30.37%
# Total Training Time: 2199.50 seconds
# Test Accuracy: 30.40%
# Epoch: 141, Loss: 1.9807271194458007, Training Time: 11.26 seconds
# Total Training Time: 2215.82 seconds
# Test Accuracy: 30.50%
# Total Training Time: 2230.65 seconds
# Test Accuracy: 30.61%
# Total Training Time: 2246.02 seconds
# Test Accuracy: 30.64%
# Total Training Time: 2260.74 seconds
# Test Accuracy: 30.70%
# Total Training Time: 2277.49 seconds
# Test Accuracy: 30.73%
# Total Training Time: 2293.06 seconds
# Test Accuracy: 30.78%
# Total Training Time: 2308.67 seconds
# Test Accuracy: 30.85%
# Total Training Time: 2323.05 seconds
# Test Accuracy: 30.89%
# Total Training Time: 2338.73 seconds
# Test Accuracy: 30.97%
# Total Training Time: 2353.20 seconds
# Test Accuracy: 31.02%
# Epoch: 151, Loss: 1.9592466259002685, Training Time: 10.60 seconds
# Total Training Time: 2368.98 seconds
# Test Accuracy: 31.13%
# Total Training Time: 2384.19 seconds
# Test Accuracy: 31.23%
# Total Training Time: 2401.19 seconds
# Test Accuracy: 31.35%
# Total Training Time: 2416.15 seconds
# Test Accuracy: 31.54%
# Total Training Time: 2433.16 seconds
# Test Accuracy: 31.69%
# Total Training Time: 2449.12 seconds
# Test Accuracy: 31.75%
# Total Training Time: 2465.45 seconds
# Test Accuracy: 31.80%
# Total Training Time: 2480.48 seconds
# Test Accuracy: 31.93%
# Total Training Time: 2496.41 seconds
# Test Accuracy: 32.04%
# Total Training Time: 2511.55 seconds
# Test Accuracy: 32.04%
# Epoch: 161, Loss: 1.9383032417297363, Training Time: 12.11 seconds
# Total Training Time: 2529.03 seconds
# Test Accuracy: 32.27%
# Total Training Time: 2544.47 seconds
# Test Accuracy: 32.35%
# Total Training Time: 2560.12 seconds
# Test Accuracy: 32.43%
# Total Training Time: 2575.07 seconds
# Test Accuracy: 32.47%
# Total Training Time: 2591.43 seconds
# Test Accuracy: 32.57%
# Total Training Time: 2605.80 seconds
# Test Accuracy: 32.63%
# Total Training Time: 2621.30 seconds
# Test Accuracy: 32.74%
# Total Training Time: 2635.77 seconds
# Test Accuracy: 32.82%
# Total Training Time: 2652.40 seconds
# Test Accuracy: 32.90%
# Total Training Time: 2667.91 seconds
# Test Accuracy: 32.89%
# Epoch: 171, Loss: 1.9165662813186646, Training Time: 10.47 seconds
# Total Training Time: 2683.46 seconds
# Test Accuracy: 32.98%
# Total Training Time: 2697.88 seconds
# Test Accuracy: 33.17%
# Total Training Time: 2714.12 seconds
# Test Accuracy: 33.21%
# Total Training Time: 2728.49 seconds
# Test Accuracy: 33.24%
# Total Training Time: 2744.04 seconds
# Test Accuracy: 33.40%
# Total Training Time: 2759.67 seconds
# Test Accuracy: 33.57%
# Total Training Time: 2776.20 seconds
# Test Accuracy: 33.67%
# Total Training Time: 2790.78 seconds
# Test Accuracy: 33.73%
# Total Training Time: 2806.65 seconds
# Test Accuracy: 33.85%
# Total Training Time: 2822.59 seconds
# Test Accuracy: 33.90%
# Epoch: 181, Loss: 1.8969073629379272, Training Time: 11.44 seconds
# Total Training Time: 2839.20 seconds
# Test Accuracy: 33.95%
# Total Training Time: 2853.93 seconds
# Test Accuracy: 33.97%
# Total Training Time: 2869.70 seconds
# Test Accuracy: 34.10%
# Total Training Time: 2884.15 seconds
# Test Accuracy: 34.21%
# Total Training Time: 2901.06 seconds
# Test Accuracy: 34.24%
# Total Training Time: 2916.94 seconds
# Test Accuracy: 34.36%
# Total Training Time: 2933.48 seconds
# Test Accuracy: 34.52%
# Total Training Time: 2948.67 seconds
# Test Accuracy: 34.46%
# Total Training Time: 2965.10 seconds
# Test Accuracy: 34.60%
# Total Training Time: 2979.64 seconds
# Test Accuracy: 34.73%
# Epoch: 191, Loss: 1.8773130130767823, Training Time: 10.44 seconds
# Total Training Time: 2995.27 seconds
# Test Accuracy: 34.74%
# Total Training Time: 3010.15 seconds
# Test Accuracy: 34.84%
# Total Training Time: 3026.45 seconds
# Test Accuracy: 34.94%
# Total Training Time: 3040.93 seconds
# Test Accuracy: 34.98%
# Total Training Time: 3057.18 seconds
# Test Accuracy: 35.01%
# Total Training Time: 3071.92 seconds
# Test Accuracy: 35.00%
# Total Training Time: 3088.36 seconds
# Test Accuracy: 35.05%
# Total Training Time: 3102.79 seconds
# Test Accuracy: 35.12%
# Total Training Time: 3118.76 seconds
# Test Accuracy: 35.20%
# Total Training Time: 3134.21 seconds
# Test Accuracy: 35.27%
# Epoch: 201, Loss: 1.8583671236038208, Training Time: 11.82 seconds
# Total Training Time: 3151.32 seconds
# Test Accuracy: 35.39%
# Total Training Time: 3166.28 seconds
# Test Accuracy: 35.45%
# Total Training Time: 3181.73 seconds
# Test Accuracy: 35.51%
# Total Training Time: 3196.52 seconds
# Test Accuracy: 35.52%
# Total Training Time: 3213.28 seconds
# Test Accuracy: 35.58%
# Total Training Time: 3228.05 seconds
# Test Accuracy: 35.66%
# Total Training Time: 3244.65 seconds
# Test Accuracy: 35.77%
# Total Training Time: 3259.76 seconds
# Test Accuracy: 35.81%
# Total Training Time: 3276.44 seconds
# Test Accuracy: 35.96%
# Total Training Time: 3291.45 seconds
# Test Accuracy: 36.06%
# Epoch: 211, Loss: 1.8402256345748902, Training Time: 10.35 seconds
# Total Training Time: 3306.91 seconds
# Test Accuracy: 36.07%
# Total Training Time: 3321.56 seconds
# Test Accuracy: 36.16%
# Total Training Time: 3338.14 seconds
# Test Accuracy: 36.16%
# Total Training Time: 3352.68 seconds
# Test Accuracy: 36.22%
# Total Training Time: 3368.35 seconds
# Test Accuracy: 36.26%
# Total Training Time: 3382.92 seconds
# Test Accuracy: 36.28%
# Total Training Time: 3399.33 seconds
# Test Accuracy: 36.33%
# Total Training Time: 3414.21 seconds
# Test Accuracy: 36.36%
# Total Training Time: 3429.90 seconds
# Test Accuracy: 36.58%
# Total Training Time: 3445.23 seconds
# Test Accuracy: 36.52%
# Epoch: 221, Loss: 1.8228638982772827, Training Time: 11.42 seconds
# Total Training Time: 3461.77 seconds
# Test Accuracy: 36.51%
# Total Training Time: 3476.23 seconds
# Test Accuracy: 36.67%
# Total Training Time: 3491.65 seconds
# Test Accuracy: 36.69%
# Total Training Time: 3506.21 seconds
# Test Accuracy: 36.69%
# Total Training Time: 3522.93 seconds
# Test Accuracy: 36.74%
# Total Training Time: 3537.33 seconds
# Test Accuracy: 36.79%
# Total Training Time: 3553.14 seconds
# Test Accuracy: 36.77%
# Total Training Time: 3569.26 seconds
# Test Accuracy: 36.94%
# Total Training Time: 3585.23 seconds
# Test Accuracy: 36.99%
# Total Training Time: 3601.72 seconds
# Test Accuracy: 36.98%
# Epoch: 231, Loss: 1.8080717420578003, Training Time: 9.45 seconds
# Total Training Time: 3616.29 seconds
# Test Accuracy: 37.02%
# Total Training Time: 3631.94 seconds
# Test Accuracy: 37.09%
# Total Training Time: 3646.58 seconds
# Test Accuracy: 37.13%
# Total Training Time: 3663.63 seconds
# Test Accuracy: 37.16%
# Total Training Time: 3678.39 seconds
# Test Accuracy: 37.19%
# Total Training Time: 3695.60 seconds
# Test Accuracy: 37.27%
# Total Training Time: 3711.30 seconds
# Test Accuracy: 37.30%
# Total Training Time: 3728.48 seconds
# Test Accuracy: 37.41%
# Total Training Time: 3744.87 seconds
# Test Accuracy: 37.52%
# Total Training Time: 3760.44 seconds
# Test Accuracy: 37.52%
# Epoch: 241, Loss: 1.7923027563095093, Training Time: 15.66 seconds
# Total Training Time: 3781.71 seconds
# Test Accuracy: 37.58%
# Total Training Time: 3801.72 seconds
# Test Accuracy: 37.61%
# Total Training Time: 3819.22 seconds
# Test Accuracy: 37.64%
# Total Training Time: 3837.59 seconds
# Test Accuracy: 37.71%
# Total Training Time: 3854.52 seconds
# Test Accuracy: 37.82%
# Total Training Time: 3871.34 seconds
# Test Accuracy: 37.87%
# Total Training Time: 3890.05 seconds
# Test Accuracy: 37.90%
# Total Training Time: 3906.00 seconds
# Test Accuracy: 37.94%
# Total Training Time: 3923.53 seconds
# Test Accuracy: 37.93%
# Total Training Time: 3938.93 seconds
# Test Accuracy: 38.00%
# Epoch: 251, Loss: 1.7775564002990722, Training Time: 10.14 seconds
# Total Training Time: 3954.30 seconds
# Test Accuracy: 38.09%
# Total Training Time: 3971.98 seconds
# Test Accuracy: 38.09%
# Total Training Time: 3986.75 seconds
# Test Accuracy: 38.21%
# Total Training Time: 4002.50 seconds
# Test Accuracy: 38.20%
# Total Training Time: 4017.37 seconds
# Test Accuracy: 38.23%
# Total Training Time: 4032.87 seconds
# Test Accuracy: 38.40%
# Total Training Time: 4047.90 seconds
# Test Accuracy: 38.37%
# Total Training Time: 4068.01 seconds
# Test Accuracy: 38.43%
# Total Training Time: 4084.41 seconds
# Test Accuracy: 38.43%
# Total Training Time: 4099.26 seconds
# Test Accuracy: 38.47%
# Epoch: 261, Loss: 1.7649605321884154, Training Time: 10.64 seconds
# Total Training Time: 4115.25 seconds
# Test Accuracy: 38.66%
# Total Training Time: 4384.15 seconds
# Test Accuracy: 38.66%
# Total Training Time: 4400.67 seconds
# Test Accuracy: 38.67%
# Total Training Time: 4417.06 seconds
# Test Accuracy: 38.69%
# Total Training Time: 4432.07 seconds
# Test Accuracy: 38.81%
# Total Training Time: 4448.26 seconds
# Test Accuracy: 38.90%
# Total Training Time: 4463.12 seconds
# Test Accuracy: 38.95%
# Total Training Time: 4478.83 seconds
# Test Accuracy: 38.94%
# Total Training Time: 4494.48 seconds
# Test Accuracy: 39.00%
# Total Training Time: 4509.51 seconds
# Test Accuracy: 39.02%
# Epoch: 271, Loss: 1.7502318954467773, Training Time: 10.71 seconds
# Total Training Time: 4525.57 seconds
# Test Accuracy: 39.08%
# Total Training Time: 4540.31 seconds
# Test Accuracy: 39.12%
# Total Training Time: 4555.93 seconds
# Test Accuracy: 39.18%
# Total Training Time: 4570.87 seconds
# Test Accuracy: 39.28%
# Total Training Time: 4586.02 seconds
# Test Accuracy: 39.44%
# Total Training Time: 4600.70 seconds
# Test Accuracy: 39.42%
# Total Training Time: 4615.90 seconds
# Test Accuracy: 39.56%
# Total Training Time: 4631.32 seconds
# Test Accuracy: 39.57%
# Total Training Time: 4646.27 seconds
# Test Accuracy: 39.61%
# Total Training Time: 4661.88 seconds
# Test Accuracy: 39.70%
# Epoch: 281, Loss: 1.7380279064178468, Training Time: 9.45 seconds
# Total Training Time: 4676.49 seconds
# Test Accuracy: 39.73%
# Total Training Time: 4691.81 seconds
# Test Accuracy: 39.81%
# Total Training Time: 4706.50 seconds
# Test Accuracy: 39.93%
# Total Training Time: 4721.84 seconds
# Test Accuracy: 40.05%
# Total Training Time: 4736.63 seconds
# Test Accuracy: 40.11%
# Total Training Time: 4751.66 seconds
# Test Accuracy: 40.10%
# Total Training Time: 4766.73 seconds
# Test Accuracy: 40.14%
# Total Training Time: 4781.90 seconds
# Test Accuracy: 40.16%
# Total Training Time: 4797.41 seconds
# Test Accuracy: 40.24%
# Total Training Time: 4812.52 seconds
# Test Accuracy: 40.21%
# Epoch: 291, Loss: 1.724761266708374, Training Time: 10.15 seconds
# Total Training Time: 4827.93 seconds
# Test Accuracy: 40.35%
# Total Training Time: 4842.57 seconds
# Test Accuracy: 40.37%
# Total Training Time: 4857.81 seconds
# Test Accuracy: 40.47%
# Total Training Time: 4872.75 seconds
# Test Accuracy: 40.49%
# Total Training Time: 4887.88 seconds
# Test Accuracy: 40.55%
# Total Training Time: 4902.53 seconds
# Test Accuracy: 40.65%
# Total Training Time: 4917.87 seconds
# Test Accuracy: 40.72%
# Total Training Time: 4933.50 seconds
# Test Accuracy: 40.71%
# Total Training Time: 4948.90 seconds
# Test Accuracy: 40.76%
# Total Training Time: 4965.49 seconds
# Test Accuracy: 40.73%
# Final Test Accuracy: 40.73%
